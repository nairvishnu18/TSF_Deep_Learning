# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import io
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning:
#
# pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.

# %%
from google.colab import files
uploaded = files.upload()

df = pd.read_csv(io.BytesIO(uploaded['SampleSuperstore.csv']))
# Out:
#      <input type="file" id="files-7fa1ac99-0852-4155-994d-4d7f293b2a3d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-7fa1ac99-0852-4155-994d-4d7f293b2a3d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving SampleSuperstore.csv to SampleSuperstore.csv

# %%
df
# Out:
#            Ship Mode    Segment  ...  Order Date   Ship Date
# 0       Second Class   Consumer  ...  07-01-2015  08-01-2015
# 1       Second Class   Consumer  ...  13-06-2015  15-06-2015
# 2       Second Class  Corporate  ...  15-02-2015  17-02-2015
# 3     Standard Class   Consumer  ...  12-05-2015  14-05-2015
# 4     Standard Class   Consumer  ...  12-05-2015  13-05-2015
# ...              ...        ...  ...         ...         ...
# 9989    Second Class   Consumer  ...         NaN         NaN
# 9990  Standard Class   Consumer  ...         NaN         NaN
# 9991  Standard Class   Consumer  ...         NaN         NaN
# 9992  Standard Class   Consumer  ...         NaN         NaN
# 9993    Second Class   Consumer  ...         NaN         NaN
#
# [9994 rows x 15 columns]

# %%
df['Profit_Ratio']=(df['Profit']/df['Sales'])*100

# %% [markdown]
# ## **USING SEABORN**

# %%
plt.figure(figsize=(8,8))
#ax = sns.regplot(x="Sales", y="Profit",color="r",data=df)
sales_profit = sns.scatterplot(x="Sales", y="Profit",hue="Profit_Ratio",data=df,size="Discount",legend='brief',sizes=(30, 250),palette='RdPu')

# %% [markdown]
# It can be observed that less sales and huge discounts on those has led to low profits.

# %%
R_P =sns.barplot(x="Region",y="Profit",data=df,palette="magma_r",)

# %%
R_D =sns.barplot(x="Region",y="Discount",data=df,palette="magma_r")

# %% [markdown]
# ## **USING PLOTY**

# %%
import plotly.graph_objects as go
plt.figure(figsize=(8,8))
fig = go.Figure(data=go.Scatter(x=df['Sales'],
                                y=df['Quantity'],
                                mode='markers')) 

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="1e5ec5d7-3627-4cee-ae55-d163a4eccad1" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("1e5ec5d7-3627-4cee-ae55-d163a4eccad1")) {
#                     Plotly.newPlot(
#                         '1e5ec5d7-3627-4cee-ae55-d163a4eccad1',
# ...
